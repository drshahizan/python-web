# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/python-web/blob/main/scrapy/SDS_Scrapy_Book_Depository.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scrapy
# !pip install crochet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scrapy
#   Downloading Scrapy-2.7.1-py2.py3-none-any.whl (271 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.5/271.5 KB 5.1 MB/s eta 0:00:00
# Collecting cryptography>=3.3
#   Downloading cryptography-39.0.0-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 42.9 MB/s eta 0:00:00
# Collecting itemloaders>=1.0.1
#   Downloading itemloaders-1.0.6-py3-none-any.whl (11 kB)
# Collecting cssselect>=0.9.1
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting queuelib>=1.4.2
#   Downloading queuelib-1.6.2-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from scrapy) (57.4.0)
# Collecting parsel>=1.5.0
#   Downloading parsel-1.7.0-py2.py3-none-any.whl (14 kB)
# Collecting PyDispatcher>=2.0.5
#   Downloading PyDispatcher-2.0.6.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml>=4.3.0 in /usr/local/lib/python3.8/dist-packages (from scrapy) (4.9.2)
# Collecting Twisted>=18.9.0
#   Downloading Twisted-22.10.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 50.8 MB/s eta 0:00:00
# Collecting pyOpenSSL>=21.0.0
#   Downloading pyOpenSSL-23.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 KB 2.7 MB/s eta 0:00:00
# Collecting service-identity>=18.1.0
#   Downloading service_identity-21.1.0-py2.py3-none-any.whl (12 kB)
# Collecting w3lib>=1.17.0
#   Downloading w3lib-2.1.1-py3-none-any.whl (21 kB)
# Collecting zope.interface>=5.1.0
#   Downloading zope.interface-5.5.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 KB 3.2 MB/s eta 0:00:00
# Collecting protego>=0.1.15
#   Downloading Protego-0.2.1-py2.py3-none-any.whl (8.2 kB)
# Collecting itemadapter>=0.1.0
#   Downloading itemadapter-0.7.0-py3-none-any.whl (10 kB)
# Collecting tldextract
#   Downloading tldextract-3.4.0-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 KB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from scrapy) (21.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=3.3->scrapy) (1.15.1)
# Collecting jmespath>=0.9.5
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from protego>=0.1.15->scrapy) (1.15.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.8/dist-packages (from service-identity>=18.1.0->scrapy) (22.2.0)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.8/dist-packages (from service-identity>=18.1.0->scrapy) (0.2.8)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.8/dist-packages (from service-identity>=18.1.0->scrapy) (0.4.8)
# Collecting Automat>=0.8.0
#   Downloading Automat-22.10.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.8/dist-packages (from Twisted>=18.9.0->scrapy) (4.4.0)
# Collecting incremental>=21.3.0
#   Downloading incremental-22.10.0-py2.py3-none-any.whl (16 kB)
# Collecting constantly>=15.1
#   Downloading constantly-15.1.0-py2.py3-none-any.whl (7.9 kB)
# Collecting hyperlink>=17.1.1
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 KB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->scrapy) (3.0.9)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.8/dist-packages (from tldextract->scrapy) (2.25.1)
# Collecting requests-file>=1.4
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.8/dist-packages (from tldextract->scrapy) (3.9.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.8/dist-packages (from tldextract->scrapy) (2.10)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=3.3->scrapy) (2.21)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.1.0->tldextract->scrapy) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.1.0->tldextract->scrapy) (1.24.3)
# Building wheels for collected packages: PyDispatcher
#   Building wheel for PyDispatcher (setup.py) ... done
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.6-py3-none-any.whl size=11959 sha256=1a75840843e4bab7e6fb79fad30f7e579cfd1be212ae94809cc2bd33ef8199fd
#   Stored in directory: /root/.cache/pip/wheels/dc/b9/4a/948b1176e084b9e3f85e4ffc3d08f817b1fdf0d973bbb94f81
# Successfully built PyDispatcher
# Installing collected packages: PyDispatcher, incremental, constantly, zope.interface, w3lib, queuelib, protego, jmespath, itemadapter, hyperlink, cssselect, Automat, Twisted, requests-file, parsel, cryptography, tldextract, service-identity, pyOpenSSL, itemloaders, scrapy
# Successfully installed Automat-22.10.0 PyDispatcher-2.0.6 Twisted-22.10.0 constantly-15.1.0 cryptography-39.0.0 cssselect-1.2.0 hyperlink-21.0.0 incremental-22.10.0 itemadapter-0.7.0 itemloaders-1.0.6 jmespath-1.0.1 parsel-1.7.0 protego-0.2.1 pyOpenSSL-23.0.0 queuelib-1.6.2 requests-file-1.5.1 scrapy-2.7.1 service-identity-21.1.0 tldextract-3.4.0 w3lib-2.1.1 zope.interface-5.5.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting crochet
#   Downloading crochet-2.0.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: Twisted>=16.0 in /usr/local/lib/python3.8/dist-packages (from crochet) (22.10.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.8/dist-packages (from crochet) (1.14.1)
# Requirement already satisfied: incremental>=21.3.0 in /usr/local/lib/python3.8/dist-packages (from Twisted>=16.0->crochet) (22.10.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.8/dist-packages (from Twisted>=16.0->crochet) (4.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from Twisted>=16.0->crochet) (22.2.0)
# Requirement already satisfied: zope.interface>=4.4.2 in /usr/local/lib/python3.8/dist-packages (from Twisted>=16.0->crochet) (5.5.2)
# Requirement already satisfied: hyperlink>=17.1.1 in /usr/local/lib/python3.8/dist-packages (from Twisted>=16.0->crochet) (21.0.0)
# Requirement already satisfied: constantly>=15.1 in /usr/local/lib/python3.8/dist-packages (from Twisted>=16.0->crochet) (15.1.0)
# Requirement already satisfied: Automat>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from Twisted>=16.0->crochet) (22.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from Automat>=0.8.0->Twisted>=16.0->crochet) (1.15.0)
# Requirement already satisfied: idna>=2.5 in /usr/local/lib/python3.8/dist-packages (from hyperlink>=17.1.1->Twisted>=16.0->crochet) (2.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from zope.interface>=4.4.2->Twisted>=16.0->crochet) (57.4.0)
# Installing collected packages: crochet
# Successfully installed crochet-2.0.0

# %%
import scrapy
from scrapy.crawler import CrawlerRunner
from crochet import setup
setup()
import requests
from scrapy.http import TextResponse

# %%
r=requests.get("https://www.bookdepository.com/search?searchTerm=big+data&search=Find+book")

# %%
response = TextResponse(r.url, body=r.text, encoding='utf-8')

# %%
title = response.css('.item-info > h3 > a::text').extract()
author = response.css('.item-info > .author > span > a > span::text').extract()
published = response.css('.item-info > .published::text').extract()
format = response.css('.item-info > .format::text').extract()
price = response.css('.item-info > .price-wrap > .price > span::text').extract()

# %%
import pandas as pd
df = pd.DataFrame(list(zip(title, author, published, format, price)), columns=['Title','Author', 'Published date', 'Foramt', 'Price'])
df
# Out:
#                                                 Title  \
# 0           \n            Weapons of Math Destruction
# 1                              \n            Big Data
# 2                              \n            Big Data
# 3                              \n            Big Data
# 4   \n            Big Data - Using SMART Big Data,...
# 5   \n            Big Data: A Very Short Introduction
# 6                        \n            Everybody Lies
# 7   \n            Big Data in Practice (use cases)...
# 8                  \n            Big Data For Dummies
# 9                              \n            Big Data
# 10              \n            The Art of Invisibility
# 11  \n            Data Science & Big Data Analytic...
# 12                   \n            Big Data, Big Dupe
# 13         \n            Spark - The Definitive Guide
# 14                \n            Big Data Fundamentals
# 15                    \n            Life After Google
# 29  \n            Paperback  US$29.99

# %%
for col in df.columns:
  df[col] = df[col].str.strip()

# %%
df['Price'] = df['Price'].str.replace('US$','', regex=False)

# %%
df['Published date'] = pd.to_datetime(df['Published date'], format='%d %b %Y')

# %%
df
# Out:
#                                                 Title  \
# 0                         Weapons of Math Destruction
# 1                                            Big Data
# 2                                            Big Data
# 3                                            Big Data
# 4   Big Data - Using SMART Big Data, Analytics and...
# 5                 Big Data: A Very Short Introduction
# 6                                      Everybody Lies
# 7   Big Data in Practice (use cases) - How 45 Succ...
# 8                                Big Data For Dummies
# 9                                            Big Data
# 10                            The Art of Invisibility
# 11  Data Science & Big Data Analytics - Discoverin...
# 12                                 Big Data, Big Dupe
# 13                       Spark - The Definitive Guide
# 14                              Big Data Fundamentals
# 15                                  Life After Google
# 16                                  Big Data Baseball
# 17                               Big Data Demystified
# 18  Loyalty 3.0: How to Revolutionize Customer and...
# 19                Statistics For Big Data For Dummies
# 20                        Weapons of Math Destruction
# 21             Privacy, Big Data, and the Public Good
# 22      Reinventing Capitalism in the Age of Big Data
# 23                                       Smart Cities
# 24                      The Rise of Big Data Policing
# 25  Big Data and Machine Learning in Quantitative ...
# 26  The Big Data-Driven Business - How to Use Big ...
# 27  Big Data MBA - Driving Business Strategies wit...
# 28  Analytics in a Big Data World - The Essential ...
# 29                       The Enterprise Big Data Lake
#
#                       Author Published date     Foramt  Price
# 0               Cathy O'Neil     2017-07-06  Paperback  12.37
# 1   Viktor Mayer-Schönberger     2014-03-04  Paperback  13.44
# 2   Viktor Mayer-Schönberger     2017-01-12  Paperback  15.43
# 3                Brian Clegg     2017-10-10  Paperback  15.95
# 4                    BB Marr     2015-03-02  Paperback  12.36
# 5             Dawn E. Holmes     2018-01-30  Paperback  15.88
# 6   Seth Stephens-Davidowitz     2017-05-09   Hardback   7.25
# 7                    BB Marr     2016-05-02   Hardback  12.95
# 8                 JS Hurwitz     2013-04-19  Paperback  13.49
# 9          Timandra Harkness     2017-08-29  Paperback  22.00
# 10          Kevin D. Mitnick     2019-09-26  Paperback   8.70
# 11           EMC Education S     2015-03-17   Hardback  11.95
# 12               Stephen Few     2018-02-01  Paperback  19.16
# 13             Bill Chambers     2018-04-03  Paperback  28.99
# 14                Thomas Erl     2016-01-15  Paperback  27.58
# 15             George Gilder     2018-08-02   Hardback  39.95
# 16            Travis Sawchik     2016-05-03  Paperback  25.20
# 17          David Stephenson     2018-02-22  Paperback  34.99
# 18             Rajat Paharia     2013-07-01   Hardback  13.67
# 19                A Anderson     2015-09-08  Paperback  17.00
# 20              Cathy O'Neil     2017-09-05  Paperback  15.89
# 21                Julia Lane     2018-11-23  Paperback  18.99
# 22  Viktor Mayer-Schönberger     2019-01-24  Paperback  63.72
# 23       Anthony M. Townsend     2014-11-17  Paperback  13.80
# 24   Andrew Guthrie Ferguson     2017-10-03   Hardback  48.14
# 25                   T Guida     2019-03-25   Hardback  59.99
# 26                   R Glass     2015-01-20   Hardback  38.38
# 27                B Schmarzo     2017-10-03  Paperback  39.99
# 28                 B Baesens     2014-07-01   Hardback  29.46
# 29              Alex Gorelik     2019-04-02  Paperback  29.99
